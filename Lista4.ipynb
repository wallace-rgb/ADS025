# %% [markdown]
# <a href="https://colab.research.google.com/github/wallace-rgb/ADS025/blob/master/Lista4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Wallace de Oliveira - 20114290034
# Lista 4

#Exercicio-1
'''forma = input('insira quando lados a forma possui(3, 4 ou 5): ')
if int(forma) < 3 or int(forma) > 5 :
  while True:
    print('VALOR INVÁLIDO.')
    forma = input('insira quando lados a forma possui(3, 4 ou 5): ')
    if int(forma) == 3 and int(forma) == 4 and int(forma) == 5 :
      break 
if int(forma) == 3 :
  base = input('insira o valor da Base da forma: ')
  altura = input('insira o valor da Altura da forma: ')
  tri = int(base) * int(altura) / 2
  print('Essa forma é um TRIÂNGULO com a ÁREA igual a:', round(tri, 2),'cm²')
elif int(forma) == 4 :
  lado = input('insira o valor do lado da forma: ')
  quad = int(lado) * int(lado)
  print('Essa forma é um QUADRADO com a ÁREA igual a:', round(quad, 2),'cm²')
elif int(forma) == 5 :
  lad = input('insira o valor do lado da forma: ')
  apo = input('insira o valor da apotema da forma: ')
  pent = (5 * int(lad)) * int(apo)
  print('Essa forma é um QUADRADO com a ÁREA igual a:', round(pent, 2),'cm²')
else:
  print('VALOR INVALIDO!!')
  print('insira um valor válido') '''


#Exercicio-2
'''forma = input('insira quando lados a forma possui(3, 4 ou 5): ')
if int(forma) < 3 :
  while True:
    print('NÃO É UM POLÍGONO.')
    forma = input('insira quando lados a forma possui(3, 4 ou 5): ')
    if int(forma) == 3 and int(forma) == 4 and int(forma) == 5 :
      break    
if int(forma) > 5 :
  while True:
    print('POLÍGONO NÃO IDENTIFICADO.')
    forma = input('insira quando lados a forma possui(3, 4 ou 5): ')
    if int(forma) == 3 and int(forma) == 4 and int(forma) == 5 :
      break
if int(forma) == 3 :
  base = input('insira o valor da Base da forma: ')
  altura = input('insira o valor da Altura da forma: ')
  tri = float(base) * float(altura) / 2
  print('Essa forma é um TRIÂNGULO com a ÁREA igual a:', round(tri, 2),'cm²')
elif int(forma) == 4 :
  lado = input('insira o valor do lado da forma: ')
  quad = float(lado) * float(lado)
  print('Essa forma é um QUADRADO com a ÁREA igual a:', round(quad, 2),'cm²')
elif int(forma) == 5 :
  lad = input('insira o valor do lado da forma: ')
  apo = input('insira o valor da apotema da forma: ')
  pent = (5 * float(lad)) * float(apo)
  print('Essa forma é um QUADRADO com a ÁREA igual a:', round(pent, 2),'cm²')'''

#Exercicio-3
'''v1 = input('insira um valor inteiro: ')
v2 = input('insira outro valor inteiro: ')
v3 = input('insira outro valor inteiro: ')
maximo = max(int(v1), int(v2), int(v3))
print('O maior valor digitado foi:', maximo)'''

#Exercicio-4
'''lado1 = input('insira o valor de um dos lado do triângulo: ')
lado2 = input('insira o valor de outro do lado do triângulo: ')
lado3 = input('insira o valor de outro do lado do triângulo: ')

if float(lado1) < 1 or float(lado2) < 1 or float(lado3) < 1 :
  while True:
    print('VALORES INVALIDOS')
    lado1 = input('insira o valor de um dos lados do triângulo: ')
    lado2 = input('insira o valor de outro do lado do triângulo: ')
    lado3 = input('insira o valor de outro do lado do triângulo: ')
    if float(lado1) >= 1 and  float(lado2) >= 1 and float(lado3) >= 1 :
      break
if float(lado1) == float(lado2) == float(lado3) :
  print('Esse triângulo é Equilátero com todos lados iguais sendo eles:', lado1,',',lado2, 'e',lado3)
elif float(lado1) == float(lado2) or float(lado1) == float(lado3) or float(lado3) == float(lado2) :
  print('Esse triângulo é Isóscele com dois lados iguais sendo eles:', lado1,',',lado2, 'e',lado3)
elif float(lado1) != float(lado2) and float(lado1) != float(lado3) and float(lado3) != float(lado2) :
  print('Esse triângulo é Escaleno com todos os lados diferentes sendo eles:', lado1,',',lado2, 'e',lado3)'''

#Exercicio-5
''' ang1 = input('insira o valor de um dos ângulos do triângulo: ')
ang2 = input('insira o valor de um outro ângulo do triângulo: ')
ang3 = input('insira o valor de um outro ângulo do triângulo: ')

if float(ang1) < 1 or float(ang2) < 1 or float(ang3) < 1 or float(ang1) > 360 or float(ang2) > 360 or float(ang3) > 360:
  while True:
    print('VALORES INVALIDOS')
    ang1 = input('insira o valor de um dos ângulos do triângulo: ')
    ang2 = input('insira o valor de um outro ângulo do triângulo: ')
    ang3 = input('insira o valor de um outro ângulo do triângulo: ')
    if float(ang1) >= 1 and float(ang2) >= 1 and float(ang3) >= 1 and float(ang1) <= 360 and float(ang2) <= 360 and float(ang3) <= 360:
      break
if float(ang1) == 90 or float(ang2) == 90 or float(ang3) == 90 :
  print('Esse triângulo é Retângulo pois possui um angulo reto de 90º')
elif float(ang1) > 90 or float(ang2) > 90 or float(ang3) > 90 :
  print('Esse triângulo é Obtusângulo pois possui um angulo obtuso maior que de 90º')
elif float(ang1) >= 1 and float(ang2) >= 1 and float(ang3) >= 1 and float(ang1) < 90 and float(ang2) < 90 and float(ang3) < 90:
  print('Esse triângulo é Acutângulo pois possui todos os angulos agudos menor que de 90º') '''

#Exercicio-6
''' x = 0
num = input('insira o valor inteiro:')
while x <= int(num) :
  print(x)
  x+=1 '''

#Ecercicio-7
'''val = input('insira um valor entre 1 e 4: ')

if float(val) < 1 or float(val) > 4:
  while True:
    print('entrada inválida')
    val = input('insira um valor entre 1 e 4: ')
    if float(val) >= 1 and float(val) <= 4:
      print('VÁLIDO, o valor digitado foi: ', val)
      break '''

#Exercicio-8
'''valor = input('insira qualquer valor inteiro: ')
while int(valor) != 0 :
  print(valor)
  valor = input('insira qualquer valor inteiro: ')
maior = max(valor)
print("o maior valor digitado foi: ", maior)
 #professor não consegui resolver esse exercicio, tentei pensar em uma logica porem não consegui 
'''

#Exercicio-9
'''numer = input('insira qualquer valor inteiro de 4 digitos : ')
if int(numer) < 1000 or int(numer) > 9999 :
  while True:
    print('VALOR INVÁLIDO!')
    numer = input('insira qualquer valor inteiro: ')
    if int(numer) >= 1000 and int(numer) <= 9999:
      break
numero = list(numer)
print('unidade:', numero[3])
print('dezena:', numero[2])
print('centena:', numero[1])
print('milhar:', numero[0])'''
# Out:
# insira qualquer valor inteiro de 4 digitos : 4558
# unidade: 8
# dezena: 5
# centena: 5
# milhar: 4
